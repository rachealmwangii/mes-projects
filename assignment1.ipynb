# %%
# !pip install pandas numpy seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ crime1.csv')
df
# Out:
#     ViolentCrime  Murder  Rape  Robbery  AggravatedAssault PropertyCrime  \
# 0          412.5     5.3  56.0     78.4              272.8      3,609.00
# 1          238.4     5.1  38.2     75.2              119.8      2,552.40
# 2          667.9     7.8  30.4    157.9              471.8      3,894.10
# 3          114.3     2.5  28.2     20.7               63.0      3,208.40
# 4          792.6     6.1  63.8    206.7              516.0      4,607.80
# ..           ...     ...   ...      ...                ...           ...
# 373        251.6    11.4   6.3     74.6              159.3         823.2
# 374        237.5    11.5   5.2     82.3              138.6      1,320.00
# 375        231.4    18.0   5.0     66.2              142.2           885
# 376         92.1     5.4   4.6     16.1               66.0           420
# 377          262    20.6   4.9    157.8               78.7      1,281.20
#
#      Burglary     Theft  MotorVehicleTheft  \
# 0         852  2,493.60              263.4
# ...

# %%
df.shape
# Out:
# (378, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ViolentCrime       377 non-null    object
#  1   Murder             378 non-null    float64
#  2   Rape               378 non-null    float64
#  3   Robbery            378 non-null    float64
#  4   AggravatedAssault  377 non-null    float64
#  5   PropertyCrime      372 non-null    object
#  6   Burglary           374 non-null    object
#  7   Theft              375 non-null    object
#  8   MotorVehicleTheft  378 non-null    float64
#  9   State              378 non-null    object
#  10  City               373 non-null    object
# dtypes: float64(5), object(6)
# memory usage: 32.6+ KB

# %%
df.describe()
# Out:
#            Murder        Rape     Robbery  AggravatedAssault  \
# count  378.000000  378.000000  378.000000         377.000000
# mean     4.574868   41.306614   77.702646         241.319098
# std      3.383652   19.506386   53.977181         137.267225
# min      0.000000    2.700000    2.300000          25.500000
# 25%      2.200000   29.000000   36.625000         144.200000
# 50%      3.800000   37.550000   67.350000         215.700000
# 75%      6.275000   51.550000  106.050000         304.900000
# max     20.600000  165.600000  351.900000         981.300000
#
#        MotorVehicleTheft
# count         378.000000
# mean          191.081746
# std           134.532918
# min            15.700000
# 25%            97.550000
# 50%           154.450000
# 75%           249.650000
# max           718.600000

# %%
df.mean()
# Out:
# ViolentCrime         357.353619
# Murder                 4.574868
# Rape                  41.306614
# Robbery               77.702646
# AggravatedAssault    241.319098
# PropertyCrime        793.866667
# Burglary             509.523184
# Theft                728.621429
# MotorVehicleTheft    191.081746
# State                       NaN
# City                        NaN
# dtype: float64

# %%
df.mode().sum()
# Out:
# ViolentCrime          357.353619
# Murder                  0.000000
# Rape                  194.100000
# Robbery               143.200000
# AggravatedAssault    5964.400000
# PropertyCrime         793.866667
# Burglary              509.523184
# Theft                 728.621429
# MotorVehicleTheft    2940.200000
# State                   0.000000
# City                    0.000000
# dtype: float64

# %%
df['Murder'].describe()
# Out:
# count    378.000000
# mean       4.574868
# std        3.383652
# min        0.000000
# 25%        2.200000
# 50%        3.800000
# 75%        6.275000
# max       20.600000
# Name: Murder, dtype: float64

# %%
df['Murder'].value_counts()
# Out:
# Murder
# 0.0     11
# 4.4      9
# 2.6      9
# 6.9      8
# 4.0      8
#         ..
# 8.3      1
# 8.7      1
# 0.4      1
# 11.6     1
# 20.6     1
# Name: count, Length: 111, dtype: int64

# %%
df['Murder'].median()
# Out:
# 3.8

# %%
df.hist(column =['Murder'], figsize=(10,6))
# Out:
# array([[<Axes: title={'center': 'Murder'}>]], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ViolentCrime         1
# Murder               0
# Rape                 0
# Robbery              0
# AggravatedAssault    1
# PropertyCrime        6
# Burglary             4
# Theft                3
# MotorVehicleTheft    0
# State                0
# City                 5
# dtype: int64

# %%
df=df.apply(pd.to_numeric, errors='coerce')
df
# Out:
#      ViolentCrime  Murder  Rape  Robbery  AggravatedAssault  PropertyCrime  \
# 0           412.5     5.3  56.0     78.4              272.8            NaN
# 1           238.4     5.1  38.2     75.2              119.8            NaN
# 2           667.9     7.8  30.4    157.9              471.8            NaN
# 3           114.3     2.5  28.2     20.7               63.0            NaN
# 4           792.6     6.1  63.8    206.7              516.0            NaN
# ..            ...     ...   ...      ...                ...            ...
# 373         251.6    11.4   6.3     74.6              159.3          823.2
# 374         237.5    11.5   5.2     82.3              138.6            NaN
# 375         231.4    18.0   5.0     66.2              142.2          885.0
# 376          92.1     5.4   4.6     16.1               66.0          420.0
# 377         262.0    20.6   4.9    157.8               78.7            NaN
#
#      Burglary  Theft  MotorVehicleTheft  State  City
# ...

# %%
df.fillna(df.mean(), inplace= True)

# %%
df.isnull().sum()
# Out:
# ViolentCrime           0
# Murder                 0
# Rape                   0
# Robbery                0
# AggravatedAssault      0
# PropertyCrime          0
# Burglary               0
# Theft                  0
# MotorVehicleTheft      0
# State                378
# City                 378
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(df['Murder'])
# Out:
# <Axes: ylabel='Murder'>

# %%
Q1=df['Murder'].quantile(0.25)
Q3=df['Murder'].quantile(0.75)
IQR= Q3-Q1
lower_bound= Q1-(1,5*IQR)
upper_bound= Q3+(1.5*IQR)
print(Q1, Q3, IQR, lower_bound, upper_bound)
# Out:
# 2.2 6.275 4.075 [  1.2   -18.175] 12.387500000000001

# %%
new_df =df[(df['Murder']>upper_bound)]
print('before removing outliers', len(df))
print('after removing outliers', len(new_df))
print(len(df), len(new_df))
# Out:
# before removing outliers 378
# after removing outliers 14
# 378 14

# %%
sns.boxplot(new_df['Murder'])
# Out:
# <Axes: ylabel='Murder'>

# %%
Q1=df['PropertyCrime'].quantile(0.25)
Q3=df['PropertyCrime'].quantile(0.75)
IQR= Q3-Q1
lower_bound= Q1-(1.5*IQR)
upper_bound= Q3+(1.5*IQR)
print(Q1, Q3, IQR, lower_bound, upper_bound)
# Out:
# 738.45 926.925 188.4749999999999 455.7375000000002 1209.6374999999998

# %%
sns.boxplot(new_df['PropertyCrime'])
# Out:
# <Axes: ylabel='PropertyCrime'>

# %%
plt.figure(figsize= (10,6))
sns.histplot(df['Murder'], bins='auto', kde=True)
plt.title('Distibution of Murder')
plt.xlabel('Murder')
plt.ylabel('Frequency')
plt.show()

# %%
df.plot.bar(x='City', y='Murder', rot=0)
# Out:
# <Axes: xlabel='City'>

# %%
df.columns
# Out:
# Index(['ViolentCrime', 'Murder', 'Rape', 'Robbery', 'AggravatedAssault',
#        'PropertyCrime', 'Burglary', 'Theft', 'MotorVehicleTheft', 'State',
#        'City'],
#       dtype='object')

# %%
df[['ViolentCrime', 'Murder', 'Rape', 'Robbery', 'AggravatedAssault',
       'PropertyCrime', 'Burglary', 'Theft', 'MotorVehicleTheft']].corr()
# Out:
#                    ViolentCrime    Murder      Rape   Robbery  \
# ViolentCrime           1.000000  0.467399  0.387121  0.707404
# Murder                 0.467399  1.000000 -0.031169  0.609573
# Rape                   0.387121 -0.031169  1.000000  0.124286
# Robbery                0.707404  0.609573  0.124286  1.000000
# AggravatedAssault      0.859877  0.405202  0.376853  0.525881
# PropertyCrime          0.030239 -0.010802  0.042015  0.008002
# Burglary               0.535285  0.351755  0.214743  0.422420
# Theft                 -0.006399 -0.058580  0.094920 -0.009145
# MotorVehicleTheft      0.515022  0.346173  0.144611  0.581557
#
#                    AggravatedAssault  PropertyCrime  Burglary     Theft  \
# ViolentCrime                0.859877       0.030239  0.535285 -0.006399
# Murder                      0.405202      -0.010802  0.351755 -0.058580
# Rape                        0.376853       0.042015  0.214743  0.094920
# ...

# %%
plt.figure(figsize= (10,6))
sns.heatmap(df.corr(), annot= True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
le= LabelEncoder()
X=df["PropertyCrime"]
Y=df["Murder"]
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
model=LinearRegression()
model.fit(df[["Murder"]], df[['PropertyCrime']])
# Out:
# LinearRegression()

# %%
model.score(df[['Murder']], df[['PropertyCrime']])
# Out:
# 0.00011668775995787861

# %%
model.predict([[70]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[788.89414927]])
